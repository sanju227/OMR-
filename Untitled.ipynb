# %%
import cv2
import numpy as np
import pandas as pd
from uuid import uuid4
from utils1 import find_paper,id_read,read_answer
import matplotlib.pyplot as plt

# %%
from skimage import io
image = io.imread('https://prepareiq-omr.s3.ap-south-1.amazonaws.com/Omr.jpg')

# %%
plt.imshow(image)

# %%
# image=cv2.imread('omr.jpg')

# %%
d=find_paper(image)

# %%
plt.imshow(image)

# %%
s_id=d[195:450,35:305]

# %%
t_id=d[195:450,355:435]

# %%
## Answers Read   
q1=d[520:645,90:195]
q2=d[695:820,90:195]
q3=d[875:1000,90:195]
q4=d[1050:1175,90:195]
q5=d[520:645,275:385]
q6=d[695:820,275:385]
q7=d[870:995,275:385]
q8=d[1050:1175,275:385]
q9=d[520:645,460:570]
q10=d[695:820,460:570]
q11=d[870:995,460:570]
q12=d[1045:1170,460:570]
q13=d[520:645,645:755]
q14=d[695:820,645:755]
q15=d[870:995,645:755]
q16=d[1045:1170,645:755]
q17=d[520:645,830:940]
q18=d[695:820,830:940]
q19=d[870:995,830:940]
q20=d[1045:1170,830:940]

# %%
def answers():
    s1=read_answer(q1) 
    s2=read_answer(q2)
    s3=read_answer(q3) 
    s4=read_answer(q4) 
    s5=read_answer(q5)
    s6=read_answer(q6)
    s7=read_answer(q7)
    s8=read_answer(q8)
    s9=read_answer(q9)
    s10=read_answer(q10)
    s11=read_answer(q11)
    s12=read_answer(q12)
    s13=read_answer(q13)
    s14=read_answer(q14)
    s15=read_answer(q15)
    s16=read_answer(q16)
    s17=read_answer(q17)
    s18=read_answer(q18)
    s19=read_answer(q19)
    s20=read_answer(q20)
    final=s1+s2+s3+s4+s5+s6+s7+s8+s9+s10+s11+s12+s13+s14+s15+s16+s17+s18+s19+s20
    return final

# %%
student_id=id_read(s_id)

# %%
test_id=id_read(t_id)

# %%
def convert(list):
        s = [str(i) for i in list]
        res = int("".join(s))
        return(res)

# %%
 student_id=convert(student_id)

# %%
 list(student_id)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14872/1161091650.py in <module>
# ----> 1 list(student_id)
#
# TypeError: 'int' object is not iterable

# %%
pd.DataFrame(list(student_id),columns='student_id')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14872/2979056088.py in <module>
# ----> 1 pd.DataFrame(list(student_id),columns='student_id')
#
# TypeError: 'int' object is not iterable

# %%
test_id=convert(test_id)

# %%
bubbled=answers()

# %%
from random import *
key=[randint(1,4)]*100

# %%
len(key)
# Out:
# 100

# %%
tuples = list(zip(bubbled, key))

# %%
df = df = pd.DataFrame(tuples, columns=['bubbled', 'key'])

# %%
df
# Out:
#     bubbled  key
# 0       1.0    2
# 1       2.0    2
# 2       3.0    2
# 3       4.0    2
# 4       1.0    2
# ..      ...  ...
# 95      4.0    2
# 96      1.0    2
# 97      2.0    2
# 98      3.0    2
# 99      4.0    2
#
# [100 rows x 2 columns]

# %%
df['key'] = df['key'].astype(float)

# %%
conditions = [df['bubbled'] == df['key'], df['bubbled'] != df['key']]
choices = ['Correct', 'Worng']
df['result'] = np.select(conditions, choices)
df
# Out:
#     bubbled  key   result
# 0       1.0  2.0    Worng
# 1       2.0  2.0  Correct
# 2       3.0  2.0    Worng
# 3       4.0  2.0    Worng
# 4       1.0  2.0    Worng
# ..      ...  ...      ...
# 95      4.0  2.0    Worng
# 96      1.0  2.0    Worng
# 97      2.0  2.0  Correct
# 98      3.0  2.0    Worng
# 99      4.0  2.0    Worng
#
# [100 rows x 3 columns]

# %%
total_correct=df['result'].value_counts()['Correct']
total_worng=df['result'].value_counts()['Worng']

# %%
total_correct
# Out:
# 25

# %%
total_worng
# Out:
# 75

# %%
ans=pd.DataFrame(df['bubbled'])

# %%
ans.to_json("answered")

# %%
a=[123456]

# %%
def convert(list):
    s = [str(i) for i in list]
    res = int("".join(s))
    return(res)
